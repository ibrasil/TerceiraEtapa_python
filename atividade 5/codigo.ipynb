# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"H:\PYTHON\etapa3\atividade 5\Tabela4.csv"

# %%
df = pd.read_csv(path, sep=';', decimal=',', encoding='latin1', header=1)
df = df.dropna(how='all', axis=1)

# %%
df
# Out:
#    Sigla  Código               Estado   1991   2000   2010   2012   2013  \
# 0     AC      12                 Acre  0.402  0.517  0.663  0.705  0.709
# 1     AL      27              Alagoas  0.370  0.471  0.631  0.657  0.653
# 2     AM      13             Amazonas  0.430  0.515  0.674  0.706  0.717
# 3     AP      16                Amapá  0.472  0.577  0.708  0.709  0.735
# 4     BA      29                Bahia  0.386  0.512  0.660  0.684  0.686
# 5     CE      23                Ceará  0.405  0.541  0.682  0.709  0.712
# 6     DF      53     Distrito Federal  0.616  0.725  0.824  0.824  0.834
# 7     ES      32       Espírito Santo  0.505  0.640  0.740  0.747  0.755
# 8     GO      52                Goiás  0.487  0.615  0.735  0.744  0.753
# 9     MA      21             Maranhão  0.357  0.476  0.639  0.669  0.682
# 10    MG      31         Minas Gerais  0.478  0.624  0.731  0.743  0.751
# 11    MS      50   Mato Grosso do Sul  0.488  0.613  0.729  0.732  0.741
# ...

# %%
df_ordenandoem2024 = df.sort_values(by="2024", ascending=False)
print(df_ordenandoem2024[["Estado", "Sigla", "2024"]])
# Out:
#                  Estado Sigla   2024
# 6      Distrito Federal    DF  0.866
# 25            São Paulo    SP  0.838
# 23       Santa Catarina    SC  0.833
# 17               Paraná    PR  0.822
# 18       Rio de Janeiro    RJ  0.819
# 22    Rio Grande do Sul    RS  0.818
# 8                 Goiás    GO  0.815
# 12          Mato Grosso    MT  0.812
# 10         Minas Gerais    MG  0.809
# 7        Espírito Santo    ES  0.804
# 26            Tocantins    TO  0.797
# 11   Mato Grosso do Sul    MS  0.797
# 20             Rondônia    RO  0.786
# 21              Roraima    RR  0.780
# 19  Rio Grande do Norte    RN  0.778
# 5                 Ceará    CE  0.773
# 2              Amazonas    AM  0.767
# 15           Pernambuco    PE  0.767
# 16                Piauí    PI  0.764
# 24              Sergipe    SE  0.761
# 14              Paraíba    PB  0.760
# 4                 Bahia    BA  0.759
# 3                 Amapá    AP  0.759
# 13                 Pará    PA  0.758
# ...

# %% [markdown]
# --------------

# %%
df["Melhora"] = df["2024"] - df["1991"]

estado_maior_melhora = df.loc[df["Melhora"].idxmax()]
print(
    f"Maior melhora: {estado_maior_melhora['Estado']} ({estado_maior_melhora['Sigla']})"
    f"com ganho de +{estado_maior_melhora['Melhora']:.3f} pontos."
)

piorou = df[df["Melhora"] < 0]
if piorou.empty:
    print("Nenhum estado apresentou queda no IDH no periodo de 1991 a 2024.")
else:
    print("Estados com redução no IDH:")
    print(piorou[["Estado", "1991", "2024", "Melhora"]])
# Out:
# Maior melhora: Tocantins (TO)com ganho de +0.428 pontos.
# Nenhum estado apresentou queda no IDH no periodo de 1991 a 2024.

# %%
df_ordenandoem2024 = df.sort_values(by="2024", ascending=False)
print("------------------------------------")
print(df_ordenandoem2024[["Estado", "Sigla", "2024"]])
# Out:
# ------------------------------------
#                  Estado Sigla   2024
# 6      Distrito Federal    DF  0.866
# 25            São Paulo    SP  0.838
# 23       Santa Catarina    SC  0.833
# 17               Paraná    PR  0.822
# 18       Rio de Janeiro    RJ  0.819
# 22    Rio Grande do Sul    RS  0.818
# 8                 Goiás    GO  0.815
# 12          Mato Grosso    MT  0.812
# 10         Minas Gerais    MG  0.809
# 7        Espírito Santo    ES  0.804
# 26            Tocantins    TO  0.797
# 11   Mato Grosso do Sul    MS  0.797
# 20             Rondônia    RO  0.786
# 21              Roraima    RR  0.780
# 19  Rio Grande do Norte    RN  0.778
# 5                 Ceará    CE  0.773
# 2              Amazonas    AM  0.767
# 15           Pernambuco    PE  0.767
# 16                Piauí    PI  0.764
# 24              Sergipe    SE  0.761
# 14              Paraíba    PB  0.760
# 4                 Bahia    BA  0.759
# 3                 Amapá    AP  0.759
# ...

# %%
anos = [c for c in df.columns if str(c).isdigit()]
id_vars = [c for c in df.columns if c not in anos and c != "Melhora"]

df_longo = df.melt(
    id_vars=id_vars, value_vars=anos, var_name="Ano", value_name="IDH"
)

df_longo["Ano"] = df_longo["Ano"].astype(int)
df_longo["IDH"] = pd.to_numeric(df_longo["IDH"], errors="coerce")

print(df_longo.head())
# Out:
#   Sigla  Código    Estado   Ano    IDH
# 0    AC      12      Acre  1991  0.402
# 1    AL      27   Alagoas  1991  0.370
# 2    AM      13  Amazonas  1991  0.430
# 3    AP      16     Amapá  1991  0.472
# 4    BA      29     Bahia  1991  0.386

# %%
df_mg = df_longo[df_longo["Sigla"] == "MG"].sort_values("Ano")

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(
    df_mg["Ano"],
    df_mg["IDH"],
    marker="o",
    color="#d95f02",
    linewidth=2,
    label="Minas Gerais",
)

ax.set_title("Evolução do IDH — Minas Gerais (1991–2024)", fontsize=12)
ax.set_xlabel("Ano")
ax.set_ylabel("IDH")
ax.set_ylim(0.3, 0.9)
ax.grid(True, linestyle="--", alpha=0.6)
ax.legend()

fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 7))

for sigla, grupo in df_longo.groupby("Sigla"):
    grupo = grupo.sort_values("Ano")
    ax.plot(
        grupo["Ano"],
        grupo["IDH"],
        marker="o",
        markersize=3,
        linewidth=1.5,
        label=sigla,
    )

ax.set_title("Evolução do IDH por Estado (1991–2024)", fontsize=14)
ax.set_xlabel("Ano")
ax.set_ylabel("IDH")
ax.set_ylim(0.3, 0.9)
ax.grid(True, linestyle="--", alpha=0.5)
ax.legend(ncol=3, bbox_to_anchor=(1.02, 1), loc="upper left", title="UF")

fig.tight_layout()
plt.show()
